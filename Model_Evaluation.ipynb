# %%
from google.colab import drive
drive.mount('gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at gdrive

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# !pwd
# !ls
# Out:
# /content
# gdrive	sample_data

# %% [markdown]
# Mounting GDrive on Colab

# %%
# !apt update
# !apt install -y cmake
# !pip install dlib
# !cmake --version
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ Packages [88.1 kB]
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:13 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# ...

# %% [markdown]
# Installling CMake

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# !ln -s "/content/drive/My Drive/BTP6/darknet/" "/content/BTP6"
# '-s' flag is used to not print the commands they are executing in the console

# %% [markdown]
# Creating a link of BTP6(from myDrive) inside content

# %%
# !pwd
# !ls
# Out:
# /content
# BTP6  gdrive  sample_data

# %%
cd /content/gdrive/My Drive/BTP6/darknet/
# Out:
# /content/gdrive/My Drive/BTP6/darknet

# %%
#Changing Variables OPENCV and GPU to include OPENCV and GPU 
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile # set OPENCV=1
# !sed -i 's/GPU=0/GPU=1/g' Makefile  # set GPU=1

# %%
# !more Makefile 
# !more Makefile  to verify the changes reflected in the Makefile
# Out:
# GPU=1
# CUDNN=0
# CUDNN_HALF=0
# OPENCV=1
# AVX=0
# OPENMP=0
# LIBSO=0
# ZED_CAMERA=0
#
# # set GPU=1 and CUDNN=1 to speedup on GPU
# # set CUDNN_HALF=1 to further speedup 3 x times (Mixed-precision on Tensor Cores
# ) GPU: Volta, Xavier, Turing and higher
# # set AVX=1 and OPENMP=1 to speedup on CPU (if error occurs then set AVX=0)
#
# USE_CPP=0
# DEBUG=0
#
# ARCH= -gencode arch=compute_30,code=sm_30 \
#       -gencode arch=compute_35,code=sm_35 \
#       -gencode arch=compute_50,code=[sm_50,compute_50] \
#       -gencode arch=compute_52,code=[sm_52,compute_52] \
# 	  -gencode arch=compute_61,code=[sm_61,compute_61]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-4c1e0dc16821> in <module>()
# ----> 1 get_ipython().system('more Makefile ')
#       2 # !more Makefile  to verify the changes reflected in the Makefile
#
# ...

# %%
# !cat Makefile 
# To view Makefile
# Out:
# GPU=1
# CUDNN=0
# CUDNN_HALF=0
# OPENCV=1
# AVX=0
# OPENMP=0
# LIBSO=0
# ZED_CAMERA=0
#
# # set GPU=1 and CUDNN=1 to speedup on GPU
# # set CUDNN_HALF=1 to further speedup 3 x times (Mixed-precision on Tensor Cores) GPU: Volta, Xavier, Turing and higher
# # set AVX=1 and OPENMP=1 to speedup on CPU (if error occurs then set AVX=0)
#
# USE_CPP=0
# DEBUG=0
#
# ARCH= -gencode arch=compute_30,code=sm_30 \
#       -gencode arch=compute_35,code=sm_35 \
#       -gencode arch=compute_50,code=[sm_50,compute_50] \
#       -gencode arch=compute_52,code=[sm_52,compute_52] \
# 	  -gencode arch=compute_61,code=[sm_61,compute_61]
#
# OS := $(shell uname)
#
# # Tesla V100
# # ARCH= -gencode arch=compute_70,code=[sm_70,compute_70]
#
# # GeForce RTX 2080 Ti, RTX 2080, RTX 2070, Quadro RTX 8000, Quadro RTX 6000, Quadro RTX 5000, Tesla T4, XNOR Tensor Cores
# # ARCH= -gencode arch=compute_75,code=[sm_75,compute_75]
#
# # Jetson XAVIER
# # ARCH= -gencode arch=compute_72,code=[sm_72,compute_72]
#
# ...

# %%
# !make
# Creating an executable File from source code
# Out:
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:909:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/http_stream.cpp -o obj/http_stream.o
# In file included from ./src/http_stream.cpp:576:0:
# ./src/httplib.h:129:0: warning: "INVALID_SOCKET" redefined
#  #define INVALID_SOCKET (-1)
#
# ...

# %%
# !cd /content/gdrive/My\ Drive/BTP6/darknet/

# %%
ls
# Out:
#  3rdparty/           'Copy of chart.png'       Makefile
#  appveyor.yml         darknet*                 net_cam_v3.sh*
#  backup/              DarknetConfig.cmake.in   obj/
#  build/               darknet.py               predictions.jpg
#  build.ps1            darknet_video.py         README.md
#  build.sh*            data/                    results/
#  cfg/                 image_yolov2.sh*         scripts/
#  chart.png            image_yolov3.sh*         src/
#  chart_yolo-obj.png   include/                 video_v2.sh*
#  cmake/               json_mjpeg_streams.sh*   video_yolov3.sh*
#  CMakeLists.txt       LICENSE

# %%
'''!./darknet detector train ./build/darknet/x64/data/obj.data ./cfg/yolo-obj.cfg ./build/darknet/x64/backup/yolo-obj_last.weights -dont_show -map'''

# %%
'''!./darknet detector test data/obj.data yolo-obj.cfg yolo-obj_8000.weights  /content/BTP6/build/darknet/x64/data/qwer1.jpg '''

# %% [markdown]
# darknet.exe detector test data/obj.data yolo-obj.cfg yolo-obj_8000.weights

# %%
# !./darknet detector test ./build/darknet/x64/data/obj.data  ./cfg/yolo-obj.cfg  ./build/darknet/x64/backup/yolo-obj_last.weights ./build/darknet/x64/data/obj/imgtest52.jpg -ext_output -num_of_clusters 9 -width 416 -height 416
# Out:
#  CUDA-version: 10000 (10010), GPU count: 1
#  OpenCV version: 3.2.0
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
# ...

# %% [markdown]
# To check accuracy mAP@IoU=50 :

# %%
# !./darknet detector map ./build/darknet/x64/data/obj.data  ./cfg/yolo-obj.cfg  ./build/darknet/x64/backup/yolo-obj_last.weights
# Out:
#  CUDA-version: 10000 (10010), GPU count: 1
#  OpenCV version: 3.2.0
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
# ...

# %%
# !./darknet detector map ./build/darknet/x64/data/obj.data  ./cfg/yolo-obj.cfg  ./build/darknet/x64/backup/yolo-obj_last.weights -iou_thresh 0.75
# Out:
#  CUDA-version: 10000 (10010), GPU count: 1
#  OpenCV version: 3.2.0
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
# ...

# %%
# !./darknet detector test ./build/darknet/x64/data/obj.data  ./cfg/yolo-obj.cfg  ./build/darknet/x64/backup/yolo-obj_last.weights  -dont_show -ext_output < ./build/darknet/x64/data/train.txt > ./build/darknet/x64/data/result.txt
# Out:
#  CUDA-version: 10010 (10010), GPU count: 1
#  OpenCV version: 3.2.0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...
